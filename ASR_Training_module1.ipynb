# %%
from google.colab import auth
from googleapiclient.discovery import build

# Authenticate to Google Colab
auth.authenticate_user()

# %%
# Build the Drive service
drive_service = build('drive', 'v3')

# List files from your Google Drive
results = drive_service.files().list(
    pageSize=10, fields="nextPageToken, files(id, name)").execute()
items = results.get('files', [])

if not items:
    print('No files found.')
else:
    print('Files:')
    for item in items:
        print(u'{0} ({1})'.format(item['name'], item['id']))
# Out:
# WARNING:google_auth_httplib2:httplib2 transport does not support per-request timeout. Set the timeout when constructing the httplib2.Http instance.
# WARNING:google_auth_httplib2:httplib2 transport does not support per-request timeout. Set the timeout when constructing the httplib2.Http instance.
# Files:
# ASR-Training.ipynb (1ZTuPCM17d1ZYlMjs9vv-9ydL7Xl-DLLT)
# common_voice_ar_19222841.wav (1KH6-t9C5xaGqPgjMesyENGD4wJ3Qo_zY)
# Waves.7z (1ypRwHLJaDW0QdR_uHEbAdaqdv4Oba87y)
# resample_errors.csv (1-nLSmftZf1C5qlLNoSFO22XzdDuinPJS)
# ASR_Project (1fnpKwZkHYHdQ05Kk7eVBHevM78TbMTON)
# Untitled0.ipynb (1yvFQ7vbz42j-ljbOMjiSD73eNArJ9jmi)
# assignment DM 1&2.pdf (1ZtjFWo69Rm9X5KbTQWOqw6juzRXGnwmO9OZT6q0KMSaNhu0eUXVQuwO_rzBDhNnXLCdSwVE)
# assignment DM 1&2.pdf (1gIWzWq8I3Rdgp3wIwkoim6k0CrMFREzw)
# assignment DM 1&2.pdf (1bMSIIj2O4Qu_9O3_NiIR7FXyAwqsaAXkZIAVL4B4p_hTyrUruZxasq3LkjimNYuaKV1OnIo)
# assignment DM 1&2.pdf (1fA4h2QMMIL0A_dGh32pUD7SENOLrRbJz)

# %%
import io
from googleapiclient.http import MediaIoBaseDownload

file_id = '1ypRwHLJaDW0QdR_uHEbAdaqdv4Oba87y'
file_name = 'Waves.7z'

request = drive_service.files().get_media(fileId=file_id)
fh = io.FileIO(file_name, 'wb')
downloader = MediaIoBaseDownload(fh, request)
done = False
while done is False:
    status, done = downloader.next_chunk()
    print(f'Download {int(status.progress() * 100)}%.')
print(f'Downloaded {file_name}.')
# Out:
# Download 1%.
# Download 3%.
# Download 4%.
# Download 6%.
# Download 8%.
# Download 9%.
# Download 11%.
# Download 13%.
# Download 14%.
# Download 16%.
# Download 17%.
# Download 19%.
# Download 21%.
# Download 22%.
# Download 24%.
# Download 26%.
# Download 27%.
# Download 29%.
# Download 31%.
# Download 32%.
# Download 34%.
# Download 35%.
# Download 37%.
# Download 39%.
# Download 40%.
# Download 42%.
# Download 44%.
# Download 45%.
# Download 47%.
# Download 48%.
# Download 50%.
# Download 52%.
# Download 53%.
# Download 55%.
# Download 57%.
# Download 58%.
# Download 60%.
# Download 62%.
# Download 63%.
# Download 65%.
# Download 66%.
# Download 68%.
# Download 70%.
# Download 71%.
# Download 73%.
# Download 75%.
# Download 76%.
# Download 78%.
# Download 79%.
# Download 81%.
# Download 83%.
# Download 84%.
# Download 86%.
# Download 88%.
# Download 89%.
# Download 91%.
# Download 93%.
# Download 94%.
# Download 96%.
# Download 97%.
# Download 99%.
# Download 100%.
# Downloaded Waves.7z.

# %%
# Install p7zip-full for extracting .7z files
get_ipython().system('apt-get update && apt-get install -y p7zip-full')
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 3,917 B in 1s (3,886 B/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# p7zip-full is already the newest version (16.02+dfsg-8).
# 0 upgraded, 0 newly installed, 0 to remove and 74 not upgraded.

# %%
# Extract the waves.7z file
!7z x Waves.7z -o/content/
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.00GHz (50653),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 6425925252 bytes (6129 MiB)
#
# Extracting archive: Waves.7z
# --
# Path = Waves.7z
# Type = 7z
# Physical Size = 6425925252
# Headers Size = 1148616
# Method = LZMA:23
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 1
# Files: 78722
# Size:       10312581943
# Compressed: 6425925252

# %%
import os
import pandas as pd

# Load CSV files
train_df = pd.read_csv('/content/train.csv')
val_df   = pd.read_csv('/content/val.csv')
test_df  = pd.read_csv('/content/test.csv')

print("Train shape:", train_df.shape)
print("Val shape:", val_df.shape)
print("Test shape:", test_df.shape)

print("\nTrain columns:", train_df.columns.tolist())
print("Val columns:", val_df.columns.tolist())
print("Test columns:", test_df.columns.tolist())

print("\nSample train rows:")
print(train_df.head(5))

print("\nSample val rows:")
print(val_df.head(5))

print("\nSample test rows:")
print(test_df.head(5))
# Out:
# Train shape: (62973, 5)
# Val shape: (7872, 5)
# Test shape: (7872, 5)
#
# Train columns: ['text', 'file_name', 'audio_path', 'duration', 'resampled_path']
# Val columns: ['text', 'file_name', 'audio_path', 'duration', 'resampled_path']
# Test columns: ['text', 'file_name', 'audio_path', 'duration', 'resampled_path']
#
# Sample train rows:
#                           text                     file_name  \
# 0                 ذلك قلم طويل  common_voice_ar_24068997.wav
# 1        جلبت ليلي انتباه فاضل  common_voice_ar_24305449.wav
# 2            لا تلجا الي العنف  common_voice_ar_19376237.wav
# 3  والاجتماع علي المناظرة ابلغ  common_voice_ar_24164640.wav
# 4        واحدهما اغلب من الاخر  common_voice_ar_24094761.wav
#
#                                           audio_path  duration  \
# 0  /kaggle/working/audio_16k/common_voice_ar_2406...  2.664036
# 1  /kaggle/working/audio_16k/common_voice_ar_2430...  3.240000
# 2  /kaggle/working/audio_16k/common_voice_ar_1937...  2.664036
# 3  /kaggle/working/audio_16k/common_voice_ar_2416...  3.708027
# 4  /kaggle/working/audio_16k/common_voice_ar_2409...  4.248027
#
#                                       resampled_path
# 0  /kaggle/working/audio_16k/common_voice_ar_2406...
# 1  /kaggle/working/audio_16k/common_voice_ar_2430...
# 2  /kaggle/working/audio_16k/common_voice_ar_1937...
# 3  /kaggle/working/audio_16k/common_voice_ar_2416...
# 4  /kaggle/working/audio_16k/common_voice_ar_2409...
#
# Sample val rows:
#                                                 text  \
# 0                 ومما زاد الطين بلة ، ان زوجها توفي
# 1                           مستكبرين به سامرا تهجرون
# 2  وكاين من اية في السماوات والارض يمرون عليها وه...
# 3        وسواء عليهم اانذرتهم ام لم تنذرهم لا يومنون
# 4                                      اين هي نعالي؟
#
#                       file_name  \
# 0  common_voice_ar_24045489.wav
# 1  common_voice_ar_24046639.wav
# 2  common_voice_ar_24034106.wav
# 3  common_voice_ar_24156411.wav
# 4  common_voice_ar_24157912.wav
#
#                                           audio_path  duration  \
# 0  /kaggle/working/audio_16k/common_voice_ar_2404...  5.220000
# 1  /kaggle/working/audio_16k/common_voice_ar_2404...  6.408027
# 2  /kaggle/working/audio_16k/common_voice_ar_2403...  6.336009
# 3  /kaggle/working/audio_16k/common_voice_ar_2415...  4.680000
# 4  /kaggle/working/audio_16k/common_voice_ar_2415...  2.448027
#
#                                       resampled_path
# 0  /kaggle/working/audio_16k/common_voice_ar_2404...
# 1  /kaggle/working/audio_16k/common_voice_ar_2404...
# 2  /kaggle/working/audio_16k/common_voice_ar_2403...
# 3  /kaggle/working/audio_16k/common_voice_ar_2415...
# 4  /kaggle/working/audio_16k/common_voice_ar_2415...
#
# Sample test rows:
#                               text                     file_name  \
# 0                    كما تزرع تحصد  common_voice_ar_24150539.wav
# 1  التقيتها صدفة في القطار اول امس  common_voice_ar_24031939.wav
# 2       واحري ان يكون اشتغالهم بها  common_voice_ar_24146756.wav
# 3                  انا لست متشايما  common_voice_ar_25191826.wav
# 4     اين استطيع ان اشتري طوابعا ؟  common_voice_ar_24069137.wav
#
#                                           audio_path  duration  \
# 0  /kaggle/working/audio_16k/common_voice_ar_2415...  2.916009
# 1  /kaggle/working/audio_16k/common_voice_ar_2403...  3.996009
# 2  /kaggle/working/audio_16k/common_voice_ar_2414...  3.888027
# 3  /kaggle/working/audio_16k/common_voice_ar_2519...  2.880000
# 4  /kaggle/working/audio_16k/common_voice_ar_2406...  5.328027
#
#                                       resampled_path
# 0  /kaggle/working/audio_16k/common_voice_ar_2415...
# 1  /kaggle/working/audio_16k/common_voice_ar_2403...
# 2  /kaggle/working/audio_16k/common_voice_ar_2414...
# 3  /kaggle/working/audio_16k/common_voice_ar_2519...
# 4  /kaggle/working/audio_16k/common_voice_ar_2406...

# %%
import re
import pandas as pd

# =========================
# 1) Load CSV files
# =========================
train_df = pd.read_csv('/content/train.csv')
val_df   = pd.read_csv('/content/val.csv')
test_df  = pd.read_csv('/content/test.csv')

print("Train:", train_df.shape)
print("Val  :", val_df.shape)
print("Test :", test_df.shape)

# =========================
# 2) Arabic text normalization
# =========================
arabic_diacritics = re.compile("""
    ّ|َ|ً|ُ|ٌ|ِ|ٍ|ْ|ـ
""", re.VERBOSE)

def normalize_arabic(text):
    if pd.isna(text):
        return ""

    text = str(text).strip()

    # Remove diacritics
    text = re.sub(arabic_diacritics, '', text)

    # Normalize common Arabic letters
    text = re.sub(r'[أإآٱ]', 'ا', text)
    text = re.sub(r'ى', 'ي', text)
    text = re.sub(r'ؤ', 'و', text)
    text = re.sub(r'ئ', 'ي', text)

    # Optional:
    # Keep ة as is for now
    # text = re.sub(r'ة', 'ه', text)

    # Remove tatweel just in case
    text = re.sub(r'ـ', '', text)

    # Keep Arabic letters, numbers, and spaces only
    text = re.sub(r'[^ء-ي0-9 ]+', ' ', text)

    # Remove extra spaces
    text = re.sub(r'\s+', ' ', text).strip()

    return text

# Apply normalization
train_df['normalized_text'] = train_df['text'].apply(normalize_arabic)
val_df['normalized_text']   = val_df['text'].apply(normalize_arabic)
test_df['normalized_text']  = test_df['text'].apply(normalize_arabic)

print("\nSample normalized text:")
print(train_df[['text', 'normalized_text']].head(10))

# =========================
# 3) Remove empty samples
# =========================
train_df = train_df[train_df['normalized_text'].str.len() > 0].reset_index(drop=True)
val_df   = val_df[val_df['normalized_text'].str.len() > 0].reset_index(drop=True)
test_df  = test_df[test_df['normalized_text'].str.len() > 0].reset_index(drop=True)

print("\nAfter removing empty texts:")
print("Train:", train_df.shape)
print("Val  :", val_df.shape)
print("Test :", test_df.shape)

# =========================
# 4) Build character vocabulary from training set only
# =========================
all_text = " ".join(train_df['normalized_text'].tolist())
vocab_chars = sorted(list(set(all_text)))

print("\nVocabulary characters:")
print(vocab_chars)
print("Vocab size without blank:", len(vocab_chars))

# Add blank token for CTC
# index 0 reserved for blank
char2idx = {'<blank>': 0}
for i, ch in enumerate(vocab_chars, start=1):
    char2idx[ch] = i

idx2char = {idx: ch for ch, idx in char2idx.items()}

print("\nTotal vocab size with blank:", len(char2idx))
print("Sample mapping:")
for k in list(char2idx.keys())[:20]:
    print(repr(k), "->", char2idx[k])

# =========================
# 5) Encode text to integer IDs
# =========================
def text_to_ids(text, char2idx):
    return [char2idx[ch] for ch in text if ch in char2idx]

train_df['label_ids'] = train_df['normalized_text'].apply(lambda x: text_to_ids(x, char2idx))
val_df['label_ids']   = val_df['normalized_text'].apply(lambda x: text_to_ids(x, char2idx))
test_df['label_ids']  = test_df['normalized_text'].apply(lambda x: text_to_ids(x, char2idx))

print("\nEncoded sample:")
print(train_df[['normalized_text', 'label_ids']].head(3))

# =========================
# 6) Choose audio path column
# =========================
# Since resampled_path already points to processed 16k audio, use it
audio_col = 'resampled_path'

# If you are in Colab and files are actually under /content/waves instead of /kaggle/working/audio_16k,
# replace the path using file_name:
# train_df[audio_col] = train_df['file_name'].apply(lambda x: f'/content/waves/{x}')
# val_df[audio_col]   = val_df['file_name'].apply(lambda x: f'/content/waves/{x}')
# test_df[audio_col]  = test_df['file_name'].apply(lambda x: f'/content/waves/{x}')

print("\nAudio column used:", audio_col)
print(train_df[[audio_col, 'normalized_text']].head())

# =========================
# 7) Save cleaned CSVs
# =========================
train_df.to_csv('/content/train_clean.csv', index=False)
val_df.to_csv('/content/val_clean.csv', index=False)
test_df.to_csv('/content/test_clean.csv', index=False)

print("\nSaved:")
print("/content/train_clean.csv")
print("/content/val_clean.csv")
print("/content/test_clean.csv")
# Out:
# Train: (62973, 5)
# Val  : (7872, 5)
# Test : (7872, 5)
#
# Sample normalized text:
#                                       text  \
# 0                             ذلك قلم طويل
# 1                    جلبت ليلي انتباه فاضل
# 2                        لا تلجا الي العنف
# 3              والاجتماع علي المناظرة ابلغ
# 4                    واحدهما اغلب من الاخر
# 5    انني مدينة لكم بالعرفان عن كل مافعلتم
# 6                           القبايل مسلمون
# 7                      روي شريك بن ابي نمر
# 8  علامة الكذاب جوده باليمين من غير مستحلف
# 9                      مجددا؟ ليس مرة اخري
#
#                            normalized_text
# 0                             ذلك قلم طويل
# 1                    جلبت ليلي انتباه فاضل
# 2                        لا تلجا الي العنف
# 3              والاجتماع علي المناظرة ابلغ
# 4                    واحدهما اغلب من الاخر
# 5    انني مدينة لكم بالعرفان عن كل مافعلتم
# 6                           القبايل مسلمون
# 7                      روي شريك بن ابي نمر
# 8  علامة الكذاب جوده باليمين من غير مستحلف
# 9                       مجددا ليس مرة اخري
#
# After removing empty texts:
# Train: (62973, 6)
# Val  : (7872, 6)
# Test : (7872, 6)
#
# Vocabulary characters:
# [' ', 'ء', 'ا', 'ب', 'ة', 'ت', 'ث', 'ج', 'ح', 'خ', 'د', 'ذ', 'ر', 'ز', 'س', 'ش', 'ص', 'ض', 'ط', 'ظ', 'ع', 'غ', 'ف', 'ق', 'ك', 'ل', 'م', 'ن', 'ه', 'و', 'ي']
# Vocab size without blank: 31
#
# Total vocab size with blank: 32
# Sample mapping:
# '<blank>' -> 0
# ' ' -> 1
# 'ء' -> 2
# 'ا' -> 3
# 'ب' -> 4
# 'ة' -> 5
# 'ت' -> 6
# 'ث' -> 7
# 'ج' -> 8
# 'ح' -> 9
# 'خ' -> 10
# 'د' -> 11
# 'ذ' -> 12
# 'ر' -> 13
# 'ز' -> 14
# 'س' -> 15
# 'ش' -> 16
# 'ص' -> 17
# 'ض' -> 18
# 'ط' -> 19
#
# Encoded sample:
#          normalized_text                                          label_ids
# 0           ذلك قلم طويل     [12, 26, 25, 1, 24, 26, 27, 1, 19, 30, 31, 26]
# 1  جلبت ليلي انتباه فاضل  [8, 26, 4, 6, 1, 26, 31, 26, 31, 1, 3, 28, 6, ...
# 2      لا تلجا الي العنف  [26, 3, 1, 6, 26, 8, 3, 1, 3, 26, 31, 1, 3, 26...
#
# Audio column used: resampled_path
#                                       resampled_path  \
# 0  /kaggle/working/audio_16k/common_voice_ar_2406...
# 1  /kaggle/working/audio_16k/common_voice_ar_2430...
# 2  /kaggle/working/audio_16k/common_voice_ar_1937...
# 3  /kaggle/working/audio_16k/common_voice_ar_2416...
# 4  /kaggle/working/audio_16k/common_voice_ar_2409...
#
#                normalized_text
# 0                 ذلك قلم طويل
# 1        جلبت ليلي انتباه فاضل
# 2            لا تلجا الي العنف
# 3  والاجتماع علي المناظرة ابلغ
# 4        واحدهما اغلب من الاخر
#
# Saved:
# /content/train_clean.csv
# /content/val_clean.csv
# /content/test_clean.csv

# %%
import os
import pandas as pd

train_df = pd.read_csv('/content/train_clean.csv')
val_df   = pd.read_csv('/content/val_clean.csv')
test_df  = pd.read_csv('/content/test_clean.csv')

# عدّل هنا لو فولدر الصوت عندك اسمه مختلف
AUDIO_DIR = '/content/waves'

train_df['resampled_path'] = train_df['file_name'].apply(lambda x: os.path.join(AUDIO_DIR, x))
val_df['resampled_path']   = val_df['file_name'].apply(lambda x: os.path.join(AUDIO_DIR, x))
test_df['resampled_path']  = test_df['file_name'].apply(lambda x: os.path.join(AUDIO_DIR, x))

print(train_df[['file_name', 'resampled_path']].head())

# Check existence
train_exists = train_df['resampled_path'].apply(os.path.exists).sum()
val_exists   = val_df['resampled_path'].apply(os.path.exists).sum()
test_exists  = test_df['resampled_path'].apply(os.path.exists).sum()

print(f"Train existing files: {train_exists}/{len(train_df)}")
print(f"Val existing files  : {val_exists}/{len(val_df)}")
print(f"Test existing files : {test_exists}/{len(test_df)}")

# Keep only rows with existing files
train_df = train_df[train_df['resampled_path'].apply(os.path.exists)].reset_index(drop=True)
val_df   = val_df[val_df['resampled_path'].apply(os.path.exists)].reset_index(drop=True)
test_df  = test_df[test_df['resampled_path'].apply(os.path.exists)].reset_index(drop=True)

print("\nAfter dropping missing files:")
print("Train:", train_df.shape)
print("Val  :", val_df.shape)
print("Test :", test_df.shape)

train_df.to_csv('/content/train_ready.csv', index=False)
val_df.to_csv('/content/val_ready.csv', index=False)
test_df.to_csv('/content/test_ready.csv', index=False)

print("\nSaved:")
print("/content/train_ready.csv")
print("/content/val_ready.csv")
print("/content/test_ready.csv")
# Out:
#                       file_name                               resampled_path
# 0  common_voice_ar_24068997.wav  /content/waves/common_voice_ar_24068997.wav
# 1  common_voice_ar_24305449.wav  /content/waves/common_voice_ar_24305449.wav
# 2  common_voice_ar_19376237.wav  /content/waves/common_voice_ar_19376237.wav
# 3  common_voice_ar_24164640.wav  /content/waves/common_voice_ar_24164640.wav
# 4  common_voice_ar_24094761.wav  /content/waves/common_voice_ar_24094761.wav
# Train existing files: 62973/62973
# Val existing files  : 7872/7872
# Test existing files : 7872/7872
#
# After dropping missing files:
# Train: (62973, 7)
# Val  : (7872, 7)
# Test : (7872, 7)
#
# Saved:
# /content/train_ready.csv
# /content/val_ready.csv
# /content/test_ready.csv

# %%
import pandas as pd
import ast

train_df = pd.read_csv('/content/train_ready.csv')

def normalize_label_ids_column(x):
    if isinstance(x, list):
        return x
    return ast.literal_eval(x)

train_df['label_ids'] = train_df['label_ids'].apply(normalize_label_ids_column)

all_text = " ".join(train_df['normalized_text'].astype(str).tolist())
vocab_chars = sorted(list(set(all_text)))

char2idx = {'<blank>': 0}
for i, ch in enumerate(vocab_chars, start=1):
    char2idx[ch] = i

idx2char = {v: k for k, v in char2idx.items()}

print("Vocab size:", len(char2idx))
print(char2idx)
# Out:
# Vocab size: 32
# {'<blank>': 0, ' ': 1, 'ء': 2, 'ا': 3, 'ب': 4, 'ة': 5, 'ت': 6, 'ث': 7, 'ج': 8, 'ح': 9, 'خ': 10, 'د': 11, 'ذ': 12, 'ر': 13, 'ز': 14, 'س': 15, 'ش': 16, 'ص': 17, 'ض': 18, 'ط': 19, 'ظ': 20, 'ع': 21, 'غ': 22, 'ف': 23, 'ق': 24, 'ك': 25, 'ل': 26, 'م': 27, 'ن': 28, 'ه': 29, 'و': 30, 'ي': 31}

# %%
import os
import ast
import torch
import torchaudio
import pandas as pd
from torch.utils.data import Dataset, DataLoader

# =========================
# Load ready CSVs
# =========================
train_df = pd.read_csv('/content/train_ready.csv')
val_df   = pd.read_csv('/content/val_ready.csv')
test_df  = pd.read_csv('/content/test_ready.csv')

def parse_label_ids(x):
    if isinstance(x, list):
        return x
    return ast.literal_eval(x)

train_df['label_ids'] = train_df['label_ids'].apply(parse_label_ids)
val_df['label_ids']   = val_df['label_ids'].apply(parse_label_ids)
test_df['label_ids']  = test_df['label_ids'].apply(parse_label_ids)

# =========================
# Audio transform
# =========================
sample_rate = 16000
n_mels = 80

mel_transform = torchaudio.transforms.MelSpectrogram(
    sample_rate=sample_rate,
    n_fft=400,
    win_length=400,
    hop_length=160,
    n_mels=n_mels
)

amplitude_to_db = torchaudio.transforms.AmplitudeToDB()

# =========================
# Dataset
# =========================
class ArabicASRDataset(Dataset):
    def __init__(self, df, audio_col='resampled_path', text_col='normalized_text', label_col='label_ids'):
        self.df = df.reset_index(drop=True)
        self.audio_col = audio_col
        self.text_col = text_col
        self.label_col = label_col

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]

        audio_path = row[self.audio_col]
        text = row[self.text_col]
        label_ids = row[self.label_col]

        waveform, sr = torchaudio.load(audio_path)

        # Convert to mono if needed
        if waveform.shape[0] > 1:
            waveform = waveform.mean(dim=0, keepdim=True)

        # Resample only if needed
        if sr != sample_rate:
            waveform = torchaudio.functional.resample(waveform, sr, sample_rate)

        # Mel spectrogram
        mel = mel_transform(waveform)          # [1, n_mels, time]
        mel = amplitude_to_db(mel)             # [1, n_mels, time]
        mel = mel.squeeze(0).transpose(0, 1)   # [time, n_mels]

        labels = torch.tensor(label_ids, dtype=torch.long)

        return {
            'features': mel,
            'labels': labels,
            'text': text,
            'audio_path': audio_path
        }

# =========================
# Collate function
# =========================
def collate_fn(batch):
    features = [item['features'] for item in batch]
    labels = [item['labels'] for item in batch]
    texts = [item['text'] for item in batch]
    audio_paths = [item['audio_path'] for item in batch]

    feature_lengths = torch.tensor([f.shape[0] for f in features], dtype=torch.long)
    label_lengths = torch.tensor([l.shape[0] for l in labels], dtype=torch.long)

    max_feat_len = max(f.shape[0] for f in features)
    n_mels = features[0].shape[1]

    padded_features = torch.zeros(len(features), max_feat_len, n_mels, dtype=torch.float32)
    for i, f in enumerate(features):
        padded_features[i, :f.shape[0], :] = f

    concatenated_labels = torch.cat(labels)

    return {
        'features': padded_features,           # [B, T, n_mels]
        'feature_lengths': feature_lengths,    # [B]
        'labels': concatenated_labels,         # [sum(label_lengths)]
        'label_lengths': label_lengths,        # [B]
        'texts': texts,
        'audio_paths': audio_paths
    }

# =========================
# Datasets
# =========================
train_dataset = ArabicASRDataset(train_df)
val_dataset   = ArabicASRDataset(val_df)
test_dataset  = ArabicASRDataset(test_df)

# =========================
# Dataloaders
# =========================
train_loader = DataLoader(
    train_dataset,
    batch_size=16,
    shuffle=True,
    num_workers=0,
    pin_memory=True,
    collate_fn=collate_fn
)

val_loader = DataLoader(
    val_dataset,
    batch_size=16,
    shuffle=False,
    num_workers=0,
    pin_memory=True,
    collate_fn=collate_fn
)

test_loader = DataLoader(
    test_dataset,
    batch_size=16,
    shuffle=False,
    num_workers=0,
    pin_memory=True,
    collate_fn=collate_fn
)

print("Datasets and loaders created successfully.")
print("Train size:", len(train_dataset))
print("Val size  :", len(val_dataset))
print("Test size :", len(test_dataset))
# Out:
# Datasets and loaders created successfully.
# Train size: 62973
# Val size  : 7872
# Test size : 7872

# %%
batch = next(iter(train_loader))

print("features shape       :", batch['features'].shape)         # [B, T, n_mels]
print("feature_lengths shape:", batch['feature_lengths'].shape)
print("labels shape         :", batch['labels'].shape)
print("label_lengths shape  :", batch['label_lengths'].shape)

print("\nExample text:")
print(batch['texts'][0])

print("\nExample audio path:")
print(batch['audio_paths'][0])
# Out:
# features shape       : torch.Size([16, 639, 80])
# feature_lengths shape: torch.Size([16])
# labels shape         : torch.Size([408])
# label_lengths shape  : torch.Size([16])
#
# Example text:
# وكنت تفضل جزيرة اكل لحوم البشر وحزام خرطوشة
#
# Example audio path:
# /content/waves/common_voice_ar_19238032.wav

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class CNNBiLSTMCTC(nn.Module):
    def __init__(
        self,
        num_classes,
        n_mels=80,
        proj_dim=256,
        lstm_hidden=256,
        lstm_layers=2,
        dropout=0.2
    ):
        super().__init__()

        self.n_mels = n_mels
        self.num_classes = num_classes
        self.proj_dim = proj_dim
        self.lstm_hidden = lstm_hidden
        self.lstm_layers = lstm_layers

        # =========================
        # CNN feature extractor
        # Input: (B, 1, T, 80)
        # =========================
        self.cnn = nn.Sequential(
            # Block 1
            nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),

            nn.Conv2d(32, 32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),

            nn.MaxPool2d(kernel_size=(2, 2), stride=(2, 2)),
            nn.Dropout(0.1),

            # Block 2
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),

            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),

            nn.MaxPool2d(kernel_size=(2, 2), stride=(2, 2)),
            nn.Dropout(0.1),

            # Block 3
            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),

            nn.MaxPool2d(kernel_size=(2, 1), stride=(2, 1)),
            nn.Dropout(dropout),
        )

        # بعد الـ CNN، أبعاد الـ frequency:
        # 80 -> 40 -> 20 -> 20
        # لأن آخر pooling = (2,1) يقلل time فقط
        cnn_freq_dim = n_mels // 4   # 80 -> 20
        cnn_out_dim = 128 * cnn_freq_dim  # 128 * 20 = 2560

        # =========================
        # Projection
        # =========================
        self.projection = nn.Sequential(
            nn.Linear(cnn_out_dim, proj_dim),
            nn.LayerNorm(proj_dim),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout)
        )

        # =========================
        # BiLSTM
        # =========================
        self.lstm = nn.LSTM(
            input_size=proj_dim,
            hidden_size=lstm_hidden,
            num_layers=lstm_layers,
            batch_first=True,
            bidirectional=True,
            dropout=dropout if lstm_layers > 1 else 0.0
        )

        # =========================
        # Output
        # =========================
        self.classifier = nn.Linear(lstm_hidden * 2, num_classes)

    def _downsample_lengths(self, input_lengths):
        """
        يحسب طول التسلسل بعد الـ CNN pooling على محور الزمن:
        Pool1: /2
        Pool2: /2
        Pool3: /2
        => total /8
        """
        lengths = input_lengths.clone()

        # Block 1 pooling (2,2)
        lengths = torch.div(lengths, 2, rounding_mode='floor')

        # Block 2 pooling (2,2)
        lengths = torch.div(lengths, 2, rounding_mode='floor')

        # Block 3 pooling (2,1)
        lengths = torch.div(lengths, 2, rounding_mode='floor')

        # حماية من الصفر
        lengths = torch.clamp(lengths, min=1)
        return lengths

    def forward(self, x, input_lengths):
        """
        x: (B, T, n_mels)
        input_lengths: (B,)
        """

        # (B, T, 80) -> (B, 1, T, 80)
        x = x.unsqueeze(1)

        # CNN
        x = self.cnn(x)
        # shape: (B, C=128, T', F')

        # Rearrange to (B, T', C*F')
        x = x.permute(0, 2, 1, 3).contiguous()
        B, T_new, C, Freq = x.shape
        x = x.view(B, T_new, C * Freq)

        # Projection
        x = self.projection(x)

        # LSTM
        x, _ = self.lstm(x)

        # Classifier
        x = self.classifier(x)

        # LogSoftmax for CTC
        log_probs = F.log_softmax(x, dim=-1)

        # lengths after CNN
        output_lengths = self._downsample_lengths(input_lengths)

        return log_probs, output_lengths

# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Device:", device)

# مهم: لازم num_classes يساوي حجم الـ vocabulary الحقيقي
num_classes = len(char2idx)

model = CNNBiLSTMCTC(
    num_classes=num_classes,
    n_mels=80,
    proj_dim=256,
    lstm_hidden=256,
    lstm_layers=2,
    dropout=0.2
).to(device)

print(model)
# Out:
# Device: cuda
# CNNBiLSTMCTC(
#   (cnn): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.1, inplace=False)
#     (8): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU(inplace=True)
#     (11): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): ReLU(inplace=True)
#     (14): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (15): Dropout(p=0.1, inplace=False)
#     (16): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (18): ReLU(inplace=True)
#     (19): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#     (20): Dropout(p=0.2, inplace=False)
#   )
#   (projection): Sequential(
#     (0): Linear(in_features=2560, out_features=256, bias=True)
#     (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.2, inplace=False)
#   )
#   (lstm): LSTM(256, 256, num_layers=2, batch_first=True, dropout=0.2, bidirectional=True)
#   (classifier): Linear(in_features=512, out_features=32, bias=True)
# )

# %%
# !pip install tqdm -q
from tqdm.auto import tqdm

# %%
import os
import json
import time
import torch
import torch.nn as nn
from tqdm.auto import tqdm

# =========================================================
# 1) CONFIG
# =========================================================

# غيره لو عايز مكان مختلف
checkpoint_dir = '/content/drive/MyDrive/ASR_checkpoints'
os.makedirs(checkpoint_dir, exist_ok=True)

last_ckpt_path = os.path.join(checkpoint_dir, 'last_checkpoint.pt')
best_ckpt_path = os.path.join(checkpoint_dir, 'best_model.pt')
history_path = os.path.join(checkpoint_dir, 'history.json')
training_state_path = os.path.join(checkpoint_dir, 'training_state.json')

# تدريب كام epoch في كل session
epochs_per_run = 3

# Early Stopping
patience = 3
min_delta = 0.001

# Optimization
learning_rate = 1e-3
weight_decay = 1e-5
max_grad_norm = 5.0

# =========================================================
# 2) DEVICE / LOSS / OPTIMIZER / SCALER
# =========================================================

use_cuda = torch.cuda.is_available()
device_type = 'cuda' if use_cuda else 'cpu'

print("Device:", device)

criterion = nn.CTCLoss(blank=0, zero_infinity=True)
optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=learning_rate,
    weight_decay=weight_decay
)

scaler = torch.amp.GradScaler(device_type, enabled=use_cuda)

# =========================================================
# 3) STATE VARIABLES
# =========================================================

best_val_loss = float('inf')
start_epoch = 0
epochs_without_improvement = 0

history = {
    'train_loss': [],
    'val_loss': []
}

# =========================================================
# 4) HELPERS
# =========================================================

def save_json(path, data):
    with open(path, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

def save_checkpoint(path, epoch, best_val_loss, epochs_without_improvement, history):
    torch.save({
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'scaler_state_dict': scaler.state_dict() if scaler is not None else None,
        'best_val_loss': best_val_loss,
        'epochs_without_improvement': epochs_without_improvement,
        'history': history
    }, path)

def load_checkpoint_if_exists():
    global best_val_loss, start_epoch, epochs_without_improvement, history

    if os.path.exists(last_ckpt_path):
        print(f"Found checkpoint: {last_ckpt_path}")
        ckpt = torch.load(last_ckpt_path, map_location=device)

        model.load_state_dict(ckpt['model_state_dict'])
        optimizer.load_state_dict(ckpt['optimizer_state_dict'])

        if ckpt.get('scaler_state_dict') is not None:
            scaler.load_state_dict(ckpt['scaler_state_dict'])

        start_epoch = ckpt.get('epoch', -1) + 1
        best_val_loss = ckpt.get('best_val_loss', float('inf'))
        epochs_without_improvement = ckpt.get('epochs_without_improvement', 0)
        history = ckpt.get('history', {'train_loss': [], 'val_loss': []})

        print(f"Resumed from epoch {start_epoch}")
        print(f"Best val loss so far: {best_val_loss:.4f}")
        print(f"epochs_without_improvement: {epochs_without_improvement}")
    else:
        print("No previous checkpoint found. Starting from scratch.")

# =========================================================
# 5) TRAIN / VALIDATE
# =========================================================

def train_one_epoch(model, loader, optimizer, criterion, scaler, device):
    model.train()
    running_loss = 0.0
    processed_batches = 0

    pbar = tqdm(loader, desc="Training", leave=False)

    for batch_idx, batch in enumerate(pbar):
        features = batch['features'].to(device, non_blocking=True)
        feature_lengths = batch['feature_lengths'].to(device, non_blocking=True)
        labels = batch['labels'].to(device, non_blocking=True)
        label_lengths = batch['label_lengths'].to(device, non_blocking=True)

        optimizer.zero_grad(set_to_none=True)

        try:
            with torch.amp.autocast(device_type=device_type, enabled=use_cuda):
                log_probs, output_lengths = model(features, feature_lengths)

                # CTC expects: (T, B, C)
                log_probs = log_probs.permute(1, 0, 2)

                loss = criterion(
                    log_probs,
                    labels,
                    output_lengths,
                    label_lengths
                )

            scaler.scale(loss).backward()

            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=max_grad_norm)

            scaler.step(optimizer)
            scaler.update()

            running_loss += loss.item()
            processed_batches += 1
            avg_loss = running_loss / processed_batches

            pbar.set_postfix({
                'train_loss': f'{avg_loss:.4f}',
                'batch_loss': f'{loss.item():.4f}'
            })

        except RuntimeError as e:
            print(f"\nSkipped train batch {batch_idx} بسبب RuntimeError: {e}")
            if use_cuda:
                torch.cuda.empty_cache()
            continue

    if processed_batches == 0:
        return float('inf')

    return running_loss / processed_batches


@torch.no_grad()
def validate_one_epoch(model, loader, criterion, device):
    model.eval()
    running_loss = 0.0
    processed_batches = 0

    pbar = tqdm(loader, desc="Validation", leave=False)

    for batch_idx, batch in enumerate(pbar):
        features = batch['features'].to(device, non_blocking=True)
        feature_lengths = batch['feature_lengths'].to(device, non_blocking=True)
        labels = batch['labels'].to(device, non_blocking=True)
        label_lengths = batch['label_lengths'].to(device, non_blocking=True)

        try:
            with torch.amp.autocast(device_type=device_type, enabled=use_cuda):
                log_probs, output_lengths = model(features, feature_lengths)
                log_probs = log_probs.permute(1, 0, 2)

                loss = criterion(
                    log_probs,
                    labels,
                    output_lengths,
                    label_lengths
                )

            running_loss += loss.item()
            processed_batches += 1
            avg_loss = running_loss / processed_batches

            pbar.set_postfix({
                'val_loss': f'{avg_loss:.4f}',
                'batch_loss': f'{loss.item():.4f}'
            })

        except RuntimeError as e:
            print(f"\nSkipped val batch {batch_idx} بسبب RuntimeError: {e}")
            if use_cuda:
                torch.cuda.empty_cache()
            continue

    if processed_batches == 0:
        return float('inf')

    return running_loss / processed_batches

# =========================================================
# 6) RESUME
# =========================================================

load_checkpoint_if_exists()

end_epoch = start_epoch + epochs_per_run
print(f"Will train from epoch {start_epoch} to {end_epoch - 1}")

# =========================================================
# 7) TRAINING LOOP WITH EARLY STOPPING
# =========================================================

for epoch in range(start_epoch, end_epoch):
    print(f"\n{'='*60}")
    print(f"Epoch {epoch + 1}")
    print(f"{'='*60}")

    epoch_start_time = time.time()

    train_loss = train_one_epoch(model, train_loader, optimizer, criterion, scaler, device)
    val_loss = validate_one_epoch(model, val_loader, criterion, device)

    history['train_loss'].append(train_loss)
    history['val_loss'].append(val_loss)

    epoch_time_min = (time.time() - epoch_start_time) / 60.0

    improvement = best_val_loss - val_loss if best_val_loss != float('inf') else 0.0
    generalization_gap = val_loss - train_loss

    print(f"Epoch {epoch + 1}:")
    print(f"  train_loss = {train_loss:.4f}")
    print(f"  val_loss   = {val_loss:.4f}")
    print(f"  improvement = {improvement:.6f}")
    print(f"  generalization_gap = {generalization_gap:.4f}")
    print(f"  time = {epoch_time_min:.2f} min")

    # -----------------------------------------
    # Save LAST checkpoint every epoch
    # -----------------------------------------
    save_checkpoint(
        path=last_ckpt_path,
        epoch=epoch,
        best_val_loss=best_val_loss,
        epochs_without_improvement=epochs_without_improvement,
        history=history
    )

    # -----------------------------------------
    # Save JSON files every epoch
    # -----------------------------------------
    save_json(history_path, history)

    save_json(training_state_path, {
        'last_completed_epoch': epoch,
        'next_start_epoch': epoch + 1,
        'best_val_loss': best_val_loss,
        'epochs_without_improvement': epochs_without_improvement,
        'patience': patience,
        'min_delta': min_delta,
        'epochs_per_run': epochs_per_run,
        'learning_rate': learning_rate,
        'weight_decay': weight_decay,
        'max_grad_norm': max_grad_norm,
        'last_train_loss': train_loss,
        'last_val_loss': val_loss,
        'last_improvement': improvement,
        'last_generalization_gap': generalization_gap,
        'last_epoch_time_min': epoch_time_min
    })

    # -----------------------------------------
    # Check improvement
    # -----------------------------------------
    if val_loss < (best_val_loss - min_delta):
        best_val_loss = val_loss
        epochs_without_improvement = 0

        save_checkpoint(
            path=best_ckpt_path,
            epoch=epoch,
            best_val_loss=best_val_loss,
            epochs_without_improvement=epochs_without_improvement,
            history=history
        )

        # Update state again after new best
        save_json(training_state_path, {
            'last_completed_epoch': epoch,
            'next_start_epoch': epoch + 1,
            'best_val_loss': best_val_loss,
            'epochs_without_improvement': epochs_without_improvement,
            'patience': patience,
            'min_delta': min_delta,
            'epochs_per_run': epochs_per_run,
            'learning_rate': learning_rate,
            'weight_decay': weight_decay,
            'max_grad_norm': max_grad_norm,
            'last_train_loss': train_loss,
            'last_val_loss': val_loss,
            'last_improvement': improvement,
            'last_generalization_gap': generalization_gap,
            'last_epoch_time_min': epoch_time_min
        })

        print(f"Saved BEST model at epoch {epoch + 1} with val_loss = {val_loss:.4f}")

    else:
        epochs_without_improvement += 1
        print(f"No significant improvement. Counter: {epochs_without_improvement}/{patience}")

        # Save updated counter
        save_checkpoint(
            path=last_ckpt_path,
            epoch=epoch,
            best_val_loss=best_val_loss,
            epochs_without_improvement=epochs_without_improvement,
            history=history
        )

        save_json(training_state_path, {
            'last_completed_epoch': epoch,
            'next_start_epoch': epoch + 1,
            'best_val_loss': best_val_loss,
            'epochs_without_improvement': epochs_without_improvement,
            'patience': patience,
            'min_delta': min_delta,
            'epochs_per_run': epochs_per_run,
            'learning_rate': learning_rate,
            'weight_decay': weight_decay,
            'max_grad_norm': max_grad_norm,
            'last_train_loss': train_loss,
            'last_val_loss': val_loss,
            'last_improvement': improvement,
            'last_generalization_gap': generalization_gap,
            'last_epoch_time_min': epoch_time_min
        })

    # -----------------------------------------
    # Early stopping
    # -----------------------------------------
    if epochs_without_improvement >= patience:
        print(f"\nEarly stopping triggered at epoch {epoch + 1}")
        print(f"Best val_loss = {best_val_loss:.4f}")
        break

print("\nTraining session complete.")
print("Saved files:")
print(" -", last_ckpt_path)
print(" -", best_ckpt_path)
print(" -", history_path)
print(" -", training_state_path)
# Out:
# Device: cuda
# No previous checkpoint found. Starting from scratch.
# Will train from epoch 0 to 2
#
# ============================================================
# Epoch 1
# ============================================================
# Training:   0%|          | 0/3936 [00:00<?, ?it/s]
# Validation:   0%|          | 0/492 [00:00<?, ?it/s]
# Epoch 1:
#   train_loss = 1.7727
#   val_loss   = 1.3433
#   improvement = 0.000000
#   generalization_gap = -0.4294
#   time = 23.11 min
# Saved BEST model at epoch 1 with val_loss = 1.3433
#
# ============================================================
# Epoch 2
# ============================================================
# Training:   0%|          | 0/3936 [00:00<?, ?it/s]
# Validation:   0%|          | 0/492 [00:00<?, ?it/s]
# Epoch 2:
#   train_loss = 1.2697
#   val_loss   = 1.0939
#   improvement = 0.249384
#   generalization_gap = -0.1758
#   time = 22.98 min
# Saved BEST model at epoch 2 with val_loss = 1.0939
#
# ============================================================
# Epoch 3
# ============================================================
# Training:   0%|          | 0/3936 [00:00<?, ?it/s]
# Validation:   0%|          | 0/492 [00:00<?, ?it/s]
# Epoch 3:
#   train_loss = 1.0749
#   val_loss   = 0.9957
#   improvement = 0.098200
#   generalization_gap = -0.0792
#   time = 22.88 min
# Saved BEST model at epoch 3 with val_loss = 0.9957
#
# Training session complete.
# Saved files:
#  - /content/drive/MyDrive/ASR_checkpoints/last_checkpoint.pt
#  - /content/drive/MyDrive/ASR_checkpoints/best_model.pt
#  - /content/drive/MyDrive/ASR_checkpoints/history.json
#  - /content/drive/MyDrive/ASR_checkpoints/training_state.json

# %%
import os
import json
import time
import torch
import torch.nn as nn
from tqdm.auto import tqdm

# =========================================================
# 1) CONFIG
# =========================================================

# غيره لو عايز مكان مختلف
checkpoint_dir = '/content/drive/MyDrive/ASR_checkpoints'
os.makedirs(checkpoint_dir, exist_ok=True)

last_ckpt_path = os.path.join(checkpoint_dir, 'last_checkpoint.pt')
best_ckpt_path = os.path.join(checkpoint_dir, 'best_model.pt')
history_path = os.path.join(checkpoint_dir, 'history.json')
training_state_path = os.path.join(checkpoint_dir, 'training_state.json')

# تدريب كام epoch في كل session
epochs_per_run = 3

# Early Stopping
patience = 3
min_delta = 0.001

# Optimization
learning_rate = 1e-3
weight_decay = 1e-5
max_grad_norm = 5.0

# =========================================================
# 2) DEVICE / LOSS / OPTIMIZER / SCALER
# =========================================================

use_cuda = torch.cuda.is_available()
device_type = 'cuda' if use_cuda else 'cpu'

print("Device:", device)

criterion = nn.CTCLoss(blank=0, zero_infinity=True)
optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=learning_rate,
    weight_decay=weight_decay
)

scaler = torch.amp.GradScaler(device_type, enabled=use_cuda)

# =========================================================
# 3) STATE VARIABLES
# =========================================================

best_val_loss = float('inf')
start_epoch = 0
epochs_without_improvement = 0

history = {
    'train_loss': [],
    'val_loss': []
}

# =========================================================
# 4) HELPERS
# =========================================================

def save_json(path, data):
    with open(path, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

def save_checkpoint(path, epoch, best_val_loss, epochs_without_improvement, history):
    torch.save({
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'scaler_state_dict': scaler.state_dict() if scaler is not None else None,
        'best_val_loss': best_val_loss,
        'epochs_without_improvement': epochs_without_improvement,
        'history': history
    }, path)

def load_checkpoint_if_exists():
    global best_val_loss, start_epoch, epochs_without_improvement, history

    if os.path.exists(last_ckpt_path):
        print(f"Found checkpoint: {last_ckpt_path}")
        ckpt = torch.load(last_ckpt_path, map_location=device)

        model.load_state_dict(ckpt['model_state_dict'])
        optimizer.load_state_dict(ckpt['optimizer_state_dict'])

        if ckpt.get('scaler_state_dict') is not None:
            scaler.load_state_dict(ckpt['scaler_state_dict'])

        start_epoch = ckpt.get('epoch', -1) + 1
        best_val_loss = ckpt.get('best_val_loss', float('inf'))
        epochs_without_improvement = ckpt.get('epochs_without_improvement', 0)
        history = ckpt.get('history', {'train_loss': [], 'val_loss': []})

        print(f"Resumed from epoch {start_epoch}")
        print(f"Best val loss so far: {best_val_loss:.4f}")
        print(f"epochs_without_improvement: {epochs_without_improvement}")
    else:
        print("No previous checkpoint found. Starting from scratch.")

# =========================================================
# 5) TRAIN / VALIDATE
# =========================================================

def train_one_epoch(model, loader, optimizer, criterion, scaler, device):
    model.train()
    running_loss = 0.0
    processed_batches = 0

    pbar = tqdm(loader, desc="Training", leave=False)

    for batch_idx, batch in enumerate(pbar):
        features = batch['features'].to(device, non_blocking=True)
        feature_lengths = batch['feature_lengths'].to(device, non_blocking=True)
        labels = batch['labels'].to(device, non_blocking=True)
        label_lengths = batch['label_lengths'].to(device, non_blocking=True)

        optimizer.zero_grad(set_to_none=True)

        try:
            with torch.amp.autocast(device_type=device_type, enabled=use_cuda):
                log_probs, output_lengths = model(features, feature_lengths)

                # CTC expects: (T, B, C)
                log_probs = log_probs.permute(1, 0, 2)

                loss = criterion(
                    log_probs,
                    labels,
                    output_lengths,
                    label_lengths
                )

            scaler.scale(loss).backward()

            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=max_grad_norm)

            scaler.step(optimizer)
            scaler.update()

            running_loss += loss.item()
            processed_batches += 1
            avg_loss = running_loss / processed_batches

            pbar.set_postfix({
                'train_loss': f'{avg_loss:.4f}',
                'batch_loss': f'{loss.item():.4f}'
            })

        except RuntimeError as e:
            print(f"\nSkipped train batch {batch_idx} بسبب RuntimeError: {e}")
            if use_cuda:
                torch.cuda.empty_cache()
            continue

    if processed_batches == 0:
        return float('inf')

    return running_loss / processed_batches


@torch.no_grad()
def validate_one_epoch(model, loader, criterion, device):
    model.eval()
    running_loss = 0.0
    processed_batches = 0

    pbar = tqdm(loader, desc="Validation", leave=False)

    for batch_idx, batch in enumerate(pbar):
        features = batch['features'].to(device, non_blocking=True)
        feature_lengths = batch['feature_lengths'].to(device, non_blocking=True)
        labels = batch['labels'].to(device, non_blocking=True)
        label_lengths = batch['label_lengths'].to(device, non_blocking=True)

        try:
            with torch.amp.autocast(device_type=device_type, enabled=use_cuda):
                log_probs, output_lengths = model(features, feature_lengths)
                log_probs = log_probs.permute(1, 0, 2)

                loss = criterion(
                    log_probs,
                    labels,
                    output_lengths,
                    label_lengths
                )

            running_loss += loss.item()
            processed_batches += 1
            avg_loss = running_loss / processed_batches

            pbar.set_postfix({
                'val_loss': f'{avg_loss:.4f}',
                'batch_loss': f'{loss.item():.4f}'
            })

        except RuntimeError as e:
            print(f"\nSkipped val batch {batch_idx} بسبب RuntimeError: {e}")
            if use_cuda:
                torch.cuda.empty_cache()
            continue

    if processed_batches == 0:
        return float('inf')

    return running_loss / processed_batches

# =========================================================
# 6) RESUME
# =========================================================

load_checkpoint_if_exists()

end_epoch = start_epoch + epochs_per_run
print(f"Will train from epoch {start_epoch} to {end_epoch - 1}")

# =========================================================
# 7) TRAINING LOOP WITH EARLY STOPPING
# =========================================================

for epoch in range(start_epoch, end_epoch):
    print(f"\n{'='*60}")
    print(f"Epoch {epoch + 1}")
    print(f"{'='*60}")

    epoch_start_time = time.time()

    train_loss = train_one_epoch(model, train_loader, optimizer, criterion, scaler, device)
    val_loss = validate_one_epoch(model, val_loader, criterion, device)

    history['train_loss'].append(train_loss)
    history['val_loss'].append(val_loss)

    epoch_time_min = (time.time() - epoch_start_time) / 60.0

    improvement = best_val_loss - val_loss if best_val_loss != float('inf') else 0.0
    generalization_gap = val_loss - train_loss

    print(f"Epoch {epoch + 1}:")
    print(f"  train_loss = {train_loss:.4f}")
    print(f"  val_loss   = {val_loss:.4f}")
    print(f"  improvement = {improvement:.6f}")
    print(f"  generalization_gap = {generalization_gap:.4f}")
    print(f"  time = {epoch_time_min:.2f} min")

    # -----------------------------------------
    # Save LAST checkpoint every epoch
    # -----------------------------------------
    save_checkpoint(
        path=last_ckpt_path,
        epoch=epoch,
        best_val_loss=best_val_loss,
        epochs_without_improvement=epochs_without_improvement,
        history=history
    )

    # -----------------------------------------
    # Save JSON files every epoch
    # -----------------------------------------
    save_json(history_path, history)

    save_json(training_state_path, {
        'last_completed_epoch': epoch,
        'next_start_epoch': epoch + 1,
        'best_val_loss': best_val_loss,
        'epochs_without_improvement': epochs_without_improvement,
        'patience': patience,
        'min_delta': min_delta,
        'epochs_per_run': epochs_per_run,
        'learning_rate': learning_rate,
        'weight_decay': weight_decay,
        'max_grad_norm': max_grad_norm,
        'last_train_loss': train_loss,
        'last_val_loss': val_loss,
        'last_improvement': improvement,
        'last_generalization_gap': generalization_gap,
        'last_epoch_time_min': epoch_time_min
    })

    # -----------------------------------------
    # Check improvement
    # -----------------------------------------
    if val_loss < (best_val_loss - min_delta):
        best_val_loss = val_loss
        epochs_without_improvement = 0

        save_checkpoint(
            path=best_ckpt_path,
            epoch=epoch,
            best_val_loss=best_val_loss,
            epochs_without_improvement=epochs_without_improvement,
            history=history
        )

        # Update state again after new best
        save_json(training_state_path, {
            'last_completed_epoch': epoch,
            'next_start_epoch': epoch + 1,
            'best_val_loss': best_val_loss,
            'epochs_without_improvement': epochs_without_improvement,
            'patience': patience,
            'min_delta': min_delta,
            'epochs_per_run': epochs_per_run,
            'learning_rate': learning_rate,
            'weight_decay': weight_decay,
            'max_grad_norm': max_grad_norm,
            'last_train_loss': train_loss,
            'last_val_loss': val_loss,
            'last_improvement': improvement,
            'last_generalization_gap': generalization_gap,
            'last_epoch_time_min': epoch_time_min
        })

        print(f"Saved BEST model at epoch {epoch + 1} with val_loss = {val_loss:.4f}")

    else:
        epochs_without_improvement += 1
        print(f"No significant improvement. Counter: {epochs_without_improvement}/{patience}")

        # Save updated counter
        save_checkpoint(
            path=last_ckpt_path,
            epoch=epoch,
            best_val_loss=best_val_loss,
            epochs_without_improvement=epochs_without_improvement,
            history=history
        )

        save_json(training_state_path, {
            'last_completed_epoch': epoch,
            'next_start_epoch': epoch + 1,
            'best_val_loss': best_val_loss,
            'epochs_without_improvement': epochs_without_improvement,
            'patience': patience,
            'min_delta': min_delta,
            'epochs_per_run': epochs_per_run,
            'learning_rate': learning_rate,
            'weight_decay': weight_decay,
            'max_grad_norm': max_grad_norm,
            'last_train_loss': train_loss,
            'last_val_loss': val_loss,
            'last_improvement': improvement,
            'last_generalization_gap': generalization_gap,
            'last_epoch_time_min': epoch_time_min
        })

    # -----------------------------------------
    # Early stopping
    # -----------------------------------------
    if epochs_without_improvement >= patience:
        print(f"\nEarly stopping triggered at epoch {epoch + 1}")
        print(f"Best val_loss = {best_val_loss:.4f}")
        break

print("\nTraining session complete.")
print("Saved files:")
print(" -", last_ckpt_path)
print(" -", best_ckpt_path)
print(" -", history_path)
print(" -", training_state_path)
# Out:
# Device: cuda
# Found checkpoint: /content/drive/MyDrive/ASR_checkpoints/last_checkpoint.pt
# Resumed from epoch 3
# Best val loss so far: 1.0939
# epochs_without_improvement: 0
# Will train from epoch 3 to 5
#
# ============================================================
# Epoch 4
# ============================================================
# Training:   0%|          | 0/3936 [00:00<?, ?it/s]
# Validation:   0%|          | 0/492 [00:00<?, ?it/s]
# Epoch 4:
#   train_loss = 0.9561
#   val_loss   = 0.9251
#   improvement = 0.168763
#   generalization_gap = -0.0309
#   time = 22.91 min
# Saved BEST model at epoch 4 with val_loss = 0.9251
#
# ============================================================
# Epoch 5
# ============================================================
# Training:   0%|          | 0/3936 [00:00<?, ?it/s]
# Validation:   0%|          | 0/492 [00:00<?, ?it/s]
# Epoch 5:
#   train_loss = 0.8722
#   val_loss   = 0.8701
#   improvement = 0.054999
#   generalization_gap = -0.0021
#   time = 23.68 min
# Saved BEST model at epoch 5 with val_loss = 0.8701
#
# ============================================================
# Epoch 6
# ============================================================
# Training:   0%|          | 0/3936 [00:00<?, ?it/s]
# Validation:   0%|          | 0/492 [00:00<?, ?it/s]
# Epoch 6:
#   train_loss = 0.8111
#   val_loss   = 0.8521
#   improvement = 0.018003
#   generalization_gap = 0.0411
#   time = 24.93 min
# Saved BEST model at epoch 6 with val_loss = 0.8521
#
# Training session complete.
# Saved files:
#  - /content/drive/MyDrive/ASR_checkpoints/last_checkpoint.pt
#  - /content/drive/MyDrive/ASR_checkpoints/best_model.pt
#  - /content/drive/MyDrive/ASR_checkpoints/history.json
#  - /content/drive/MyDrive/ASR_checkpoints/training_state.json
